# %% [markdown]
# Autoencoder with Fashion MNIST
# ===
#
# - A simple verion of NO deep convolutional layers.
# - Speed up by binary_crossentropy in calculating reconstruction loss.

# %% [markdown]
# # Setup

# %%
import sklearn
import tensorflow as tf
from tensorflow import keras

# Common imports
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# @title utility function to render image
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %% [markdown]
# # Load training data

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]
X_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (55000, 28, 28)

# %% [markdown]
# # Autoencoder
#
# - To make the learning speed faster, binary crossentropy can be used to calculate the loss by rounding the pixcel values to 0 or 1.
# - This is possible because the trainign data is gray scaled.

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(
        tf.round(y_true), # round to 0 or 1 to use binary_crossentropy
        tf.round(y_pred))

# %%
LATENT_DIM = 30
IMAGE_SIZE = 28
HIDDEN_DIM = 100
LEARNING_RATE = 0.5

encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(IMAGE_SIZE, IMAGE_SIZE)),
    keras.layers.Dense(HIDDEN_DIM, activation='selu'),
    keras.layers.Dense(LATENT_DIM, activation='selu'),
])
decoder = keras.models.Sequential([
    keras.layers.Dense(HIDDEN_DIM, input_shape=(LATENT_DIM,)),
    keras.layers.Dense(IMAGE_SIZE * IMAGE_SIZE, activation='sigmoid'),
    keras.layers.Reshape((IMAGE_SIZE, IMAGE_SIZE))
])
autoencoder = keras.models.Sequential([encoder, decoder])
autoencoder.compile(
    # 多ラベル２項分類問題として扱い、個々のピクセルの明度はピクセルを黒にすべき確率を表す
    # 回帰問題とするよりも収束が早くなる
    loss='binary_crossentropy',
    optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE),

    # 正解率は個々のピクセルのラベルが0か1であることを前提としているのでカスタム指標が必要
    # 正解と予測を0か1に丸めてから正解率を計算する必要がある
    metrics=[rounded_accuracy]
)
print(autoencoder.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 30)                81530
#
#  sequential_4 (Sequential)   (None, 28, 28)            82284
#
# =================================================================
# Total params: 163814 (639.90 KB)
# Trainable params: 163814 (639.90 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# # Train

# %%
history = autoencoder.fit(X_train, X_train, epochs=20,
                          validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.3661 - rounded_accuracy: 0.8628 - val_loss: 0.3247 - val_rounded_accuracy: 0.9007
# Epoch 2/20
# 1719/1719 [==============================] - 16s 10ms/step - loss: 0.3163 - rounded_accuracy: 0.9065 - val_loss: 0.3139 - val_rounded_accuracy: 0.9109
# Epoch 3/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3088 - rounded_accuracy: 0.9130 - val_loss: 0.3083 - val_rounded_accuracy: 0.9157
# Epoch 4/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3045 - rounded_accuracy: 0.9167 - val_loss: 0.3047 - val_rounded_accuracy: 0.9176
# Epoch 5/20
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.3015 - rounded_accuracy: 0.9194 - val_loss: 0.3022 - val_rounded_accuracy: 0.9212
# Epoch 6/20
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.2991 - rounded_accuracy: 0.9216 - val_loss: 0.2998 - val_rounded_accuracy: 0.9229
# Epoch 7/20
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.2971 - rounded_accuracy: 0.9234 - val_loss: 0.2980 - val_rounded_accuracy: 0.9240
# Epoch 8/20
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.2955 - rounded_accuracy: 0.9249 - val_loss: 0.2972 - val_rounded_accuracy: 0.9227
# Epoch 9/20
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.2943 - rounded_accuracy: 0.9260 - val_loss: 0.2955 - val_rounded_accuracy: 0.9268
# Epoch 10/20
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.2933 - rounded_accuracy: 0.9269 - val_loss: 0.2948 - val_rounded_accuracy: 0.9260
# Epoch 11/20
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.2924 - rounded_accuracy: 0.9277 - val_loss: 0.2938 - val_rounded_accuracy: 0.9278
# Epoch 12/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2917 - rounded_accuracy: 0.9283 - val_loss: 0.2937 - val_rounded_accuracy: 0.9264
# Epoch 13/20
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.2911 - rounded_accuracy: 0.9288 - val_loss: 0.2928 - val_rounded_accuracy: 0.9281
# Epoch 14/20
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2906 - rounded_accuracy: 0.9293 - val_loss: 0.2926 - val_rounded_accuracy: 0.9302
# Epoch 15/20
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2901 - rounded_accuracy: 0.9297 - val_loss: 0.2917 - val_rounded_accuracy: 0.9293
# Epoch 16/20
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.2897 - rounded_accuracy: 0.9301 - val_loss: 0.2915 - val_rounded_accuracy: 0.9289
# Epoch 17/20
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.2893 - rounded_accuracy: 0.9304 - val_loss: 0.2911 - val_rounded_accuracy: 0.9295
# Epoch 18/20
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.2890 - rounded_accuracy: 0.9307 - val_loss: 0.2906 - val_rounded_accuracy: 0.9309
# Epoch 19/20
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2887 - rounded_accuracy: 0.9310 - val_loss: 0.2907 - val_rounded_accuracy: 0.9291
# Epoch 20/20
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.2884 - rounded_accuracy: 0.9312 - val_loss: 0.2902 - val_rounded_accuracy: 0.9318

# %% [markdown]
# Retrieve some image samples and pass through autoencoder
# and compare the inputs with the reconstructed ones.

# %%
def show_reconstructions(model, images=X_valid, n_images=10):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
show_reconstructions(autoencoder)
# Out:
# 1/1 [==============================] - 0s 22ms/step
